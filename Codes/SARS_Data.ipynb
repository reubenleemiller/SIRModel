# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
csv_data = pd.read_csv("SARS_Data.csv")
Days = csv_data["Days"]
T = csv_data["T"]
F = csv_data["F"]
H = csv_data["H"]
O = csv_data["O"]
coefficients = np.polyfit(Days, H, deg=1)
polynomial_function = np.poly1d(coefficients)
y_poly_pred = polynomial_function(Days)
plt.figure()
plt.title("Plot of New Infections From Health Care Setting (H)",family='serif')
plt.xlabel("Time (Days)",family='serif')
plt.ylabel("New Cases",family='serif')
plt.plot(Days,H,label="H",linestyle="",linewidth=0.2,marker="o",markersize=2)
plt.plot(Days, y_poly_pred, label="Linear fit for H", linestyle="-",linewidth=0.5, color="red")
plt.legend(loc='best')
plt.xticks(family='serif')
plt.yticks(family='serif')
equation_text = f"y = {coefficients[0]:.4f}x + {coefficients[1]:.4f}"
plt.show()
print(equation_text)
# Out:
# y = 0.0158x + 1.6627

# %%
coefficients = np.polyfit(Days, T, deg=1)
polynomial_function = np.poly1d(coefficients)
y_poly_pred = polynomial_function(Days)
plt.figure()
plt.title("Plot of New Infections From Travel Setting (T)",family='serif')
plt.xlabel("Time (Days)",family='serif')
plt.ylabel("New Cases",family='serif')
plt.plot(Days,T,label="T",linestyle="",linewidth=0.2,marker="o",markersize=2)
plt.plot(Days, y_poly_pred, label="Linear fit for T", linestyle="-",linewidth=0.5, color="red")
plt.legend(loc='best')
plt.xticks(family='serif')
plt.yticks(family='serif')
equation_text = f"y = {coefficients[0]:.4f}x + {coefficients[1]:.4f}"
plt.show()
print(equation_text)
# Out:
# y = -0.0027x + 0.2149

# %%
coefficients = np.polyfit(Days, F, deg=1)
polynomial_function = np.poly1d(coefficients)
y_poly_pred = polynomial_function(Days)
plt.figure()
plt.title("Plot of New Infections From Household Setting (F)",family='serif')
plt.xlabel("Time (Days)",family='serif')
plt.ylabel("New Cases",family='serif')
plt.plot(Days,F,label="F",linestyle="",linewidth=0.2,marker="o",markersize=2)
plt.plot(Days, y_poly_pred, label="Linear fit for F", linestyle="-",linewidth=0.5, color="red")
plt.legend(loc='best')
plt.xticks(family='serif')
plt.yticks(family='serif')
equation_text = f"y = {coefficients[0]:.4f}x + {coefficients[1]:.4f}"
plt.show()
print(equation_text)
# Out:
# y = -0.0067x + 0.9668

# %%
coefficients = np.polyfit(Days, O, deg=1)
polynomial_function = np.poly1d(coefficients)
y_poly_pred = polynomial_function(Days)
plt.figure()
plt.title("Plot of New Infections From Other Setting (O)",family='serif')
plt.xlabel("Time (Days)",family='serif')
plt.ylabel("New Cases",family='serif')
plt.plot(Days,O,label="O",linestyle="",linewidth=0.2,marker="o",markersize=2)
plt.plot(Days, y_poly_pred, label="Linear fit for O", linestyle="-",linewidth=0.5, color="red")
plt.legend(loc='best')
plt.xticks(family='serif')
plt.yticks(family='serif')
equation_text = f"y = {coefficients[0]:.4f}x + {coefficients[1]:.4f}"
plt.show()
print(equation_text)
# Out:
# y = -0.0011x + 0.1416
